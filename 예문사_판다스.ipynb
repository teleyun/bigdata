# %%
import numpy as np
import pandas as pd
housing_df = pd.read_csv('california_housing_train.csv')
housing_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
housing_df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing_median_age = housing_df[['housing_median_age']]
housing_median_age.value_counts().head()
# Out:
# housing_median_age
# 52.0                  1052
# 36.0                   715
# 35.0                   692
# 16.0                   635
# 17.0                   576
# dtype: int64

# %%
housing_df['Age_0'] = np.arange(17000)
housing_df.head()
# help(np.sort)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  Age_0
# 0      1015.0       472.0         1.4936             66900.0      0
# 1      1129.0       463.0         1.8200             80100.0      1
# 2       333.0       117.0         1.6509             85700.0      2
# 3       515.0       226.0         3.1917             73400.0      3
# 4       624.0       262.0         1.9250             65500.0      4

# %%
housing_df['Age_by_10'] = (housing_df['housing_median_age'] //10) * 10
housing_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
value_counts = housing_df['Age_by_10'].value_counts()
value_counts
# Out:
# 30.0    4770
# 20.0    3985
# 10.0    3739
# 40.0    2223
# 50.0    1196
# 0.0     1087
# Name: Age_by_10, dtype: int64

# %%
housing_drop_df = housing_df.drop('Age_0', axis = 1)
# housing_drop_df = housing_df.drop(0, axis=0)
housing_drop_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
housing_df
drop_result = housing_df.drop(['Age_0', 'Age_by_10'], axis=1, inplace=False)
drop_result.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
housing_drop_df = housing_df.drop([0, 1, 2], axis=0)
housing_drop_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# 5        -114.58     33.63                29.0       1387.0           236.0
# 6        -114.58     33.61                25.0       2907.0           680.0
# 7        -114.59     34.83                41.0        812.0           168.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
housing_df[['longitude', 'total_rooms']]
# Out:
#        longitude  total_rooms
# 0        -114.31       5612.0
# 1        -114.47       7650.0
# 2        -114.56        720.0
# 3        -114.57       1501.0
# 4        -114.57       1454.0
# ...          ...          ...
# 16995    -124.26       2217.0
# 16996    -124.27       2349.0
# 16997    -124.30       2677.0
# 16998    -124.30       2672.0
# 16999    -124.35       1820.0
#
# [17000 rows x 2 columns]

# %%
housing_df.index[1:2]
# Out:
# RangeIndex(start=1, stop=2, step=1)

# %%
housing_df[housing_df['housing_median_age']==30].head()
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 26     -115.37     32.82                30.0       1602.0           322.0
# 50     -115.52     34.22                30.0        540.0           136.0
# 101    -115.59     32.69                30.0        935.0           177.0
# 343    -116.90     33.98                30.0       3915.0           672.0
# 427    -116.96     34.83                30.0       1211.0           289.0
#
#      population  households  median_income  median_house_value  Age_0  \
# 26       1130.0       335.0         3.5735             71100.0     26
# 50        122.0        63.0         1.3333             42500.0     50
# 101       649.0       148.0         2.5769             94400.0    101
# 343      1820.0       643.0         3.6339             98600.0    343
# 427       611.0       230.0         1.6667             44700.0    427
#
#      Age_by_10
# 26        30.0
# 50        30.0
# 101       30.0
# 343       30.0
# 427       30.0

# %%
housing_df[(housing_df['housing_median_age'] > 30) & (housing_df['total_rooms'] < 100) & (housing_df['median_income'] > 10)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6030     -118.22     34.06                52.0         48.0             6.0
# 13055    -121.87     37.46                43.0         91.0            12.0
# 14501    -122.14     37.50                46.0         30.0             4.0
# 16309    -122.50     37.79                52.0          8.0             1.0
#
#        population  households  median_income  median_house_value  Age_0  \
# 6030         41.0        10.0        10.2264            112500.0   6030
# 13055        58.0        16.0        15.0001            500001.0  13055
# 14501        13.0         5.0        15.0001            500001.0  14501
# 16309        13.0         1.0        15.0001            500001.0  16309
#
#        Age_by_10
# 6030        50.0
# 13055       40.0
# 14501       40.0
# 16309       50.0

# %%
housing_df.iloc[0:1, 1:3]
# Out:
#    latitude  housing_median_age
# 0     34.19                15.0

# %%
housing_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  Age_0  Age_by_10
# 0      1015.0       472.0         1.4936             66900.0      0       10.0
# 1      1129.0       463.0         1.8200             80100.0      1       10.0
# 2       333.0       117.0         1.6509             85700.0      2       10.0
# 3       515.0       226.0         3.1917             73400.0      3       10.0
# 4       624.0       262.0         1.9250             65500.0      4       20.0

# %%
housing_df.loc[:, 'longitude':'total_rooms']
# Out:
#        longitude  latitude  housing_median_age  total_rooms
# 0        -114.31     34.19                15.0       5612.0
# 1        -114.47     34.40                19.0       7650.0
# 2        -114.56     33.69                17.0        720.0
# 3        -114.57     33.64                14.0       1501.0
# 4        -114.57     33.57                20.0       1454.0
# ...          ...       ...                 ...          ...
# 16995    -124.26     40.58                52.0       2217.0
# 16996    -124.27     40.69                36.0       2349.0
# 16997    -124.30     41.84                17.0       2677.0
# 16998    -124.30     41.80                19.0       2672.0
# 16999    -124.35     40.54                52.0       1820.0
#
# [17000 rows x 4 columns]

# %%
housing_df.loc[housing_df['housing_median_age'] ==30, ['housing_median_age', 'total_bedrooms']]
# Out:
#        housing_median_age  total_bedrooms
# 26                   30.0           322.0
# 50                   30.0           136.0
# 101                  30.0           177.0
# 343                  30.0           672.0
# 427                  30.0           289.0
# ...                   ...             ...
# 16786                30.0           930.0
# 16803                30.0           331.0
# 16926                30.0           393.0
# 16974                30.0           366.0
# 16985                30.0           634.0
#
# [384 rows x 2 columns]

# %%
housing_df.sort_values(by = 'housing_median_age', ascending = False)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16999    -124.35     40.54                52.0       1820.0           300.0
# 14561    -122.16     38.05                52.0       1888.0           457.0
# 6551     -118.28     34.18                52.0       2602.0           418.0
# 4420     -118.03     33.99                52.0       2792.0           461.0
# 14579    -122.16     37.74                52.0        771.0           147.0
# ...          ...       ...                 ...          ...             ...
# 1880     -117.28     34.06                 2.0       1658.0           290.0
# 4274     -118.01     34.55                 2.0       2701.0           530.0
# 2771     -117.70     33.51                 2.0       5261.0           763.0
# 10993    -120.93     37.65                 1.0       2254.0           328.0
# 13708    -122.00     38.23                 1.0       2062.0           343.0
#
# ...

# %%
housing_df.loc[0:100, ['Age_by_10', 'total_rooms']].sort_values(by=['Age_by_10', 'total_rooms'], ascending = True)
# Out:
#      Age_by_10  total_rooms
# 95         0.0        805.0
# 100        0.0       2183.0
# 98         0.0       2494.0
# 75         0.0       2652.0
# 58         0.0       2804.0
# ..         ...          ...
# 7         40.0        812.0
# 12        40.0       1291.0
# 9         40.0       1497.0
# 67        40.0       2429.0
# 82        40.0       2511.0
#
# [101 rows x 2 columns]

# %%
housing_df.loc[housing_df['housing_median_age'] == 30, ['housing_median_age', 'total_rooms']].mean()
# Out:
# housing_median_age      30.000000
# total_rooms           2346.848958
# dtype: float64

# %%
housing_df.groupby('housing_median_age').mean()
# Out:
#                      longitude   latitude  total_rooms  total_bedrooms  \
# housing_median_age
# 1.0                -121.465000  37.940000  2158.000000      335.500000
# 2.0                -119.035306  35.410816  5237.102041      871.448980
# 3.0                -118.798478  35.164783  6920.326087     1190.826087
# 4.0                -118.805093  34.987764  6065.614907     1068.192547
# 5.0                -118.789497  35.095327  4926.261307      910.924623
# 6.0                -118.915969  35.183798  4365.062016      821.550388
# 7.0                -119.165497  35.627616  5672.907285     1047.350993
# 8.0                -119.375056  35.785899  4076.786517      779.252809
# 9.0                -119.324186  35.654942  3813.465116      727.401163
# 10.0               -119.350841  35.881681  3518.482301      681.508850
# 11.0               -119.517837  35.930288  3971.105769      768.932692
# 12.0               -119.405000  35.806458  4216.661458      838.843750
# ...

# %%
housing_df.groupby(['housing_median_age']).housing_median_age.mean().head()
# Out:
# housing_median_age
# 1.0    1.0
# 2.0    2.0
# 3.0    3.0
# 4.0    4.0
# 5.0    5.0
# Name: housing_median_age, dtype: float64

# %%
housing_df.groupby(['housing_median_age'])['total_rooms', 'total_bedrooms'].mean().head()
# Out:
# C:\Users\teley\AppData\Local\Temp/ipykernel_7960/2011704687.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   housing_df.groupby(['housing_median_age'])['total_rooms', 'total_bedrooms'].mean().head()
#                     total_rooms  total_bedrooms
# housing_median_age
# 1.0                 2158.000000      335.500000
# 2.0                 5237.102041      871.448980
# 3.0                 6920.326087     1190.826087
# 4.0                 6065.614907     1068.192547
# 5.0                 4926.261307      910.924623

# %%
housing_df.groupby('housing_median_age')['total_rooms', 'total_bedrooms'].agg(['mean', 'var', 'max', 'min', 'sum']).head()
# Out:
# C:\Users\teley\AppData\Local\Temp/ipykernel_7960/671857773.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   housing_df.groupby('housing_median_age')['total_rooms', 'total_bedrooms'].agg(['mean', 'var', 'max', 'min', 'sum']).head()
#                     total_rooms                                           \
#                            mean           var      max     min       sum
# housing_median_age
# 1.0                 2158.000000  1.843200e+04   2254.0  2062.0    4316.0
# 2.0                 5237.102041  2.639489e+07  21897.0    96.0  256618.0
# 3.0                 6920.326087  2.949001e+07  21060.0   475.0  318335.0
# 4.0                 6065.614907  3.588887e+07  37937.0     2.0  976564.0
# 5.0                 4926.261307  1.882155e+07  25187.0   111.0  980326.0
#
#                    total_bedrooms
#                              mean            var     max    min       sum
# ...

# %%
# housing_df.info()

housing_df['Age_na'] = np.nan
housing_df.isna().sum()
# Out:
# longitude                 0
# latitude                  0
# housing_median_age        0
# total_rooms               0
# total_bedrooms            0
# population                0
# households                0
# median_income             0
# median_house_value        0
# Age_0                     0
# Age_by_10                 0
# Age_na                17000
# dtype: int64

# %%
housing_df['Age_na'] = housing_df['Age_na'].fillna(housing_df['housing_median_age'].mean())
df_des = housing_df.describe()
df_des
# housing_df.describe().iloc[1,2]
(df_des.loc['mean','housing_median_age'] - df_des.loc['mean', 'Age_na']).astype('float16')
# Out:
# -0.0
